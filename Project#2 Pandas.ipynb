# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup

# %%
USA_df = pd.read_csv('Resources/number-of-deaths-by-risk-factor.csv')
NOD_df = USA_df.loc[(USA_df['Entity'] == 'United States') &(USA_df['Year'] >= 2000)]
NOD_df.head()
# Out:
#              Entity Code  Year  Outdoor air pollution   \
# 6340  United States  USA  2000                  103749
# 6341  United States  USA  2001                  102077
# 6342  United States  USA  2002                  100492
# 6343  United States  USA  2003                   97219
# 6344  United States  USA  2004                   92987
#
#        High systolic blood pressure  Diet high in sodium  \
# 6340                         522147                38216
# 6341                         515688                38703
# 6342                         505748                39216
# 6343                         489705                39321
# 6344                         467423                38771
#
#       Diet low in whole grains  Alcohol use  Diet low in fruits  \
# 6340                    104042        80477               39042
# 6341                    103247        83379               38688
# 6342                    102511        86645               38423
# ...

# %%
NER_df = pd.read_csv('Resources/number-of-deaths-by-risk-factor.csv')
NOD2_df = NER_df.loc[(NER_df['Entity'] == 'Niger') &(NER_df['Year'] >= 2000)]
NOD2_df.head()
# Out:
#      Entity Code  Year  Outdoor air pollution    High systolic blood pressure  \
# 4120  Niger  NER  2000                    1987                           5446
# 4121  Niger  NER  2001                    2038                           5653
# 4122  Niger  NER  2002                    2048                           5845
# 4123  Niger  NER  2003                    2088                           6068
# 4124  Niger  NER  2004                    2030                           6148
#
#       Diet high in sodium  Diet low in whole grains  Alcohol use  \
# 4120                  487                       679          566
# 4121                  507                       702          585
# 4122                  527                       724          601
# 4123                  551                       752          624
# 4124                  562                       760          632
#
#       Diet low in fruits  Unsafe water source  ...  High body-mass index  \
# ...

# %%
CAR_df = pd.read_csv('Resources/number-of-deaths-by-risk-factor.csv')
NOD3_df = CAR_df.loc[(CAR_df['Entity'] == 'Central African Republic') &(CAR_df['Year'] >= 2000)]
NOD3_df.head()
# Out:
#                         Entity Code  Year  Outdoor air pollution   \
# 1060  Central African Republic  CAF  2000                     653
# 1061  Central African Republic  CAF  2001                     653
# 1062  Central African Republic  CAF  2002                     651
# 1063  Central African Republic  CAF  2003                     658
# 1064  Central African Republic  CAF  2004                     666
#
#        High systolic blood pressure  Diet high in sodium  \
# 1060                           3432                  237
# 1061                           3469                  241
# 1062                           3524                  246
# 1063                           3572                  251
# 1064                           3625                  256
#
#       Diet low in whole grains  Alcohol use  Diet low in fruits  \
# 1060                       367         1862                 386
# 1061                       372         1868                 391
# ...

# %%
COG_df = pd.read_csv('Resources/number-of-deaths-by-risk-factor.csv')
NOD4_df = COG_df.loc[(COG_df['Entity'] == 'Congo') &(COG_df['Year'] >= 2000)]
NOD4_df.head()
# Out:
#      Entity Code  Year  Outdoor air pollution    High systolic blood pressure  \
# 1240  Congo  COG  2000                     825                           3382
# 1241  Congo  COG  2001                     823                           3318
# 1242  Congo  COG  2002                     824                           3290
# 1243  Congo  COG  2003                     850                           3379
# 1244  Congo  COG  2004                     876                           3448
#
#       Diet high in sodium  Diet low in whole grains  Alcohol use  \
# 1240                  236                       357         1015
# 1241                  233                       352          972
# 1242                  232                       350          942
# 1243                  240                       361          966
# 1244                  246                       370          974
#
#       Diet low in fruits  Unsafe water source  ...  High body-mass index  \
# ...

# %%
USA_df = pd.read_csv('Resources/share-of-adult-men-overweight-or-obese-vs-daily-supply-of-calories.csv')
Ob_df = USA_df.loc[(USA_df['Entity'] == 'United States') &(USA_df['Year'] >= 2000)]
Ob_df = Ob_df.rename(columns={"Daily caloric supply (OWID based on UN FAO & historical sources)":"Daily Caloric Supply","Entity":"Country"})
Ob_df = Ob_df.drop({ 'Continent','Overweight or Obese (NCDRisC (2017))','Code'}, axis = 1)
Ob_df.head()
# Out:
#              Country  Year  Daily Caloric Supply  \
# 53857  United States  2000                3755.0
# 53858  United States  2001                3707.0
# 53859  United States  2002                3783.0
# 53860  United States  2003                3777.0
# 53861  United States  2004                3809.0
#
#        Population (historical estimates)
# 53857                        282398560.0
# 53858                        285470496.0
# 53859                        288350240.0
# 53860                        291109824.0
# 53861                        293947872.0

# %%
NER_df = pd.read_csv('Resources/share-of-adult-men-overweight-or-obese-vs-daily-supply-of-calories.csv')
Ob2_df = NER_df.loc[(NER_df['Entity'] == 'Niger') &(NER_df['Year'] >= 2000)]
Ob2_df = Ob2_df.rename(columns={"Daily caloric supply (OWID based on UN FAO & historical sources)":"Daily Caloric Supply","Entity":"Country"})
Ob2_df = Ob2_df.drop({ 'Continent','Overweight or Obese (NCDRisC (2017))','Code'}, axis = 1)
Ob2_df.head()
# Out:
#       Country  Year  Daily Caloric Supply  Population (historical estimates)
# 36165   Niger  2000                2328.0                         11622673.0
# 36166   Niger  2001                2341.0                         12031431.0
# 36167   Niger  2002                2309.0                         12456520.0
# 36168   Niger  2003                2401.0                         12900793.0
# 36169   Niger  2004                2453.0                         13366889.0

# %%
CAR_df = pd.read_csv('Resources/share-of-adult-men-overweight-or-obese-vs-daily-supply-of-calories.csv')
Ob3_df = CAR_df.loc[(CAR_df['Entity'] == 'Central African Republic') &(CAR_df['Year'] >= 2000)]
Ob3_df = Ob3_df.rename(columns={"Daily caloric supply (OWID based on UN FAO & historical sources)":"Daily Caloric Supply","Entity":"Country"})
Ob3_df = Ob3_df.drop({ 'Continent','Overweight or Obese (NCDRisC (2017))','Code'}, axis = 1)
Ob3_df.head()
# Out:
#                        Country  Year  Daily Caloric Supply  \
# 9501  Central African Republic  2000                1983.0
# 9502  Central African Republic  2001                1988.0
# 9503  Central African Republic  2002                1996.0
# 9504  Central African Republic  2003                1966.0
# 9505  Central African Republic  2004                1989.0
#
#       Population (historical estimates)
# 9501                          3759174.0
# 9502                          3844780.0
# 9503                          3930654.0
# 9504                          4026853.0
# 9505                          4115146.0

# %%
COG_df = pd.read_csv('Resources/share-of-adult-men-overweight-or-obese-vs-daily-supply-of-calories.csv')
Ob4_df = COG_df.loc[(COG_df['Entity'] == 'Congo') &(COG_df['Year'] >= 2000)]
Ob4_df = Ob4_df.rename(columns={"Daily caloric supply (OWID based on UN FAO & historical sources)":"Daily Caloric Supply","Entity":"Country"})
Ob4_df = Ob4_df.drop({ 'Continent','Overweight or Obese (NCDRisC (2017))','Code'}, axis = 1)
Ob4_df.head()
# Out:
#       Country  Year  Daily Caloric Supply  Population (historical estimates)
# 11039   Congo  2000                2177.0                          3134034.0
# 11040   Congo  2001                2232.0                          3254105.0
# 11041   Congo  2002                2259.0                          3331170.0
# 11042   Congo  2003                2236.0                          3424664.0
# 11043   Congo  2004                2263.0                          3543018.0

# %%
USA_df = pd.read_csv('Resources/InsufficientPhysicalActivity.csv')
IPA_df = USA_df.loc[(USA_df['Location'] == 'United States of America')]
IPA_df = IPA_df.rename(columns={"Location":"Country","Period":"Year", "Dim1":"Sex"})
IPA_df = IPA_df.drop({ 'SpatialDimValueCode','Dim1 type','Dim1ValueCode','ParentLocationCode','Period type','ParentLocation','Location type','IndicatorCode', 'Indicator','ValueType','FactValueUoM', 'FactValueNumericLowPrefix', 'IsLatestYear', 'FactValueNumericPrefix', 'FactValueNumericHighPrefix', 'FactValueTranslationID', 'FactComments', 'Dim3', 'DataSource' , 'Dim3ValueCode', 'DataSourceDimValueCode', 'DataSource', 'Dim2 type' , 'Dim2', 'Dim2ValueCode', 'Dim3 type' , 'DateModified','IsLatestYear', 'Language' }, axis = 1)
IPA_df.head()
# Out:
#                       Country  Year         Sex  FactValueNumeric  \
# 273  United States of America  2016        Male             31.72
# 382  United States of America  2016  Both sexes             40.01
# 432  United States of America  2016      Female             48.02
#
#      FactValueNumericLow  FactValueNumericHigh                  Value
# 273                25.78                 38.31  31.72 [25.78 – 38.31]
# 382                33.05                 47.35  40.01 [33.05 – 47.35]
# 432                40.07                 56.08  48.02 [40.07 – 56.08]

# %%
NER_df = pd.read_csv('Resources/InsufficientPhysicalActivity.csv')
IPA2_df = NER_df.loc[(NER_df['Location'] == 'Niger')]
IPA2_df = IPA2_df.rename(columns={"Location":"Country","Period":"Year", "Dim1":"Sex"})
IPA2_df = IPA2_df.drop({'SpatialDimValueCode','Dim1 type','Dim1ValueCode','ParentLocationCode','Period type','ParentLocation','Location type','IndicatorCode', 'Indicator','ValueType','FactValueUoM', 'FactValueNumericLowPrefix', 'IsLatestYear', 'FactValueNumericPrefix', 'FactValueNumericHighPrefix', 'FactValueTranslationID', 'FactComments', 'Dim3', 'DataSource' , 'Dim3ValueCode', 'DataSourceDimValueCode', 'DataSource', 'Dim2 type' , 'Dim2', 'Dim2ValueCode', 'Dim3 type' , 'DateModified','IsLatestYear', 'Language' }, axis = 1)
IPA2_df.head()
# Out:
#     Country  Year         Sex  FactValueNumeric  FactValueNumericLow  \
# 101   Niger  2016        Male             19.72                14.33
# 129   Niger  2016  Both sexes             22.38                16.52
# 165   Niger  2016      Female             25.02                18.68
#
#      FactValueNumericHigh                  Value
# 101                 26.48  19.72 [14.33 – 26.48]
# 129                 29.57  22.38 [16.52 – 29.57]
# 165                 32.62  25.02 [18.68 – 32.62]

# %%
CAR_df = pd.read_csv('Resources/InsufficientPhysicalActivity.csv')
IPA3_df = CAR_df.loc[(CAR_df['Location'] == 'Central African Republic')]
IPA3_df = IPA3_df.rename(columns={"Location":"Country","Period":"Year", "Dim1":"Sex"})
IPA3_df = IPA3_df.drop({'SpatialDimValueCode','Dim1 type','Dim1ValueCode','ParentLocationCode','Period type','ParentLocation','Location type','IndicatorCode', 'Indicator','ValueType','FactValueUoM', 'FactValueNumericLowPrefix', 'IsLatestYear', 'FactValueNumericPrefix', 'FactValueNumericHighPrefix', 'FactValueTranslationID', 'FactComments', 'Dim3', 'DataSource' , 'Dim3ValueCode', 'DataSourceDimValueCode', 'DataSource', 'Dim2 type' , 'Dim2', 'Dim2ValueCode', 'Dim3 type' , 'DateModified','IsLatestYear', 'Language' }, axis = 1)
IPA3_df.head()
# Out:
#                      Country  Year         Sex  FactValueNumeric  \
# 21  Central African Republic  2016        Male             12.60
# 39  Central African Republic  2016  Both sexes             14.31
# 51  Central African Republic  2016      Female             15.94
#
#     FactValueNumericLow  FactValueNumericHigh                  Value
# 21                 9.67                 16.26    12.6 [9.67 – 16.26]
# 39                10.91                 18.54  14.31 [10.91 – 18.54]
# 51                12.09                 20.71  15.94 [12.09 – 20.71]

# %%
COG_df = pd.read_csv('Resources/InsufficientPhysicalActivity.csv')
IPA4_df = COG_df.loc[(COG_df['Location'] == 'Congo')]
IPA4_df = IPA4_df.rename(columns={"Location":"Country","Period":"Year", "Dim1":"Sex"})
IPA4_df = IPA4_df.drop({'SpatialDimValueCode','Dim1 type','Dim1ValueCode','ParentLocationCode','Period type','ParentLocation','Location type','IndicatorCode', 'Indicator','ValueType','FactValueUoM', 'FactValueNumericLowPrefix', 'IsLatestYear', 'FactValueNumericPrefix', 'FactValueNumericHighPrefix', 'FactValueTranslationID', 'FactComments', 'Dim3', 'DataSource' , 'Dim3ValueCode', 'DataSourceDimValueCode', 'DataSource', 'Dim2 type' , 'Dim2', 'Dim2ValueCode', 'Dim3 type' , 'DateModified','IsLatestYear', 'Language' }, axis = 1)
IPA4_df.head()
# Out:
#     Country  Year         Sex  FactValueNumeric  FactValueNumericLow  \
# 161   Congo  2016        Male             24.76                18.92
# 210   Congo  2016  Both sexes             28.03                21.63
# 266   Congo  2016      Female             31.27                24.31
#
#      FactValueNumericHigh                  Value
# 161                 31.68  24.76 [18.92 – 31.68]
# 210                 35.46  28.03 [21.63 – 35.46]
# 266                 39.19  31.27 [24.31 – 39.19]
